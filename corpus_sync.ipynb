# %% [markdown]
# <a href="https://colab.research.google.com/github/gretiere545/corpus/blob/main/corpus_sync.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fabrique des Corpus ASAMLA

# %% [markdown]
# ## Phase 1 : Initialisation d'un nouveau Corpus

# %%
# !export PYTHONIOENCODING=utf8
# !pip install gspread-formatting
import pandas as pd
import numpy as np
import base64
import uuid
import zlib
import binascii
import random
import os
import json
import secrets
pd.set_option("display.width",1000)
# Ce bout de code pour pouvoir downloader des fichiers sur le drive
from google.colab import drive
drive.mount('/content/drive')
# Ce bout de code pour pouvoir downloader des google sheets dans des dataframes
from google.colab import auth
auth.authenticate_user()
import gspread
from gspread_formatting import *
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())
# %cd /content/drive/MyDrive/Trad-Union/Corpus/ASAMLA
# Out:
# Collecting gspread-formatting
#   Downloading gspread_formatting-1.0.6-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: gspread>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from gspread-formatting) (3.4.2)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from gspread>=3.0.0->gspread-formatting) (2.23.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.7/dist-packages (from gspread>=3.0.0->gspread-formatting) (1.35.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-formatting) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-formatting) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-formatting) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-formatting) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth->gspread>=3.0.0->gspread-formatting) (4.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth->gspread>=3.0.0->gspread-formatting) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth->gspread>=3.0.0->gspread-formatting) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth->gspread>=3.0.0->gspread-formatting) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth->gspread>=3.0.0->gspread-formatting) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth->gspread>=3.0.0->gspread-formatting) (0.4.8)
# Installing collected packages: gspread-formatting
# Successfully installed gspread-formatting-1.0.6
# Mounted at /content/drive
# /content/drive/MyDrive/Trad-Union/Corpus/ASAMLA

# %%
def check_id (id):
  return True

# %%
def make_unique_id():
  id = str(uuid.uuid4())[:8]
  if check_id(id) is False:
    make_unique_id()
  return id

# %%
def format_feuille(wb, nom_onglet):
  # onglet
  ws = wb.worksheet(nom_onglet)
  # Format de la partie gauche
  fmt = cellFormat(
      backgroundColor=color(0.91, 0.96, 0.93),
      textFormat=textFormat(bold=False, foregroundColor=color(0,0,0), fontSize='10'),
      horizontalAlignment='LEFT'
      )
  format_cell_range(ws, 'A:B', fmt)

  # format de l'entete
  fmt = cellFormat(
      backgroundColor=color(0.7725,0.8431,0.7922),
      textFormat=textFormat(bold=True, foregroundColor=color(0,0,0), fontSize='10'),
      horizontalAlignment='LEFT'
      )
  format_cell_range(ws, '1', fmt)
  
  # on gèle l'entete et les colonnes de gauche
  set_frozen(ws, rows=1, cols=2)
  set_column_width(ws, 'A', 0)
  set_column_width(ws, 'B', 400)
  set_column_width(ws, 'C:', 600)
  #set_column_width(ws, 'D:', 200)

# %% [markdown]
# Référentiels Corpus de travail

# %%
# Corpus Français Médical Vaccination
corpus_fr_med_vac = "asamla-corpus_francais_med_vac-v1.2"
corpus_fr_med_vac_uri = "https://docs.google.com/spreadsheets/d/1-2SDHCFR5JOHCc4MiYSMo4V8yG7kfHbpIKV3q9ci6wE"
# Corpus Français Médical Médecine Générale
corpus_fr_med_gen = "ASAMLA - Corpus Médical Médecine Générale-Liste des expressions à traduire-v1.0"
corpus_fr_med_gen_uri = "https://docs.google.com/spreadsheets/d/1M3CFSpAGII25qCl0apYrRPX-DmpdxDFLLB_Ob-MX8DQ"

# %%
# Corpus Toutes Langues Médical Vaccination
corpus_trad_med_vac = "ASAMLA - Corpus Médical Vaccination-v2.0"
corpus_trad_med_vac_uri = "https://docs.google.com/spreadsheets/d/1CclzYfFCW4srA3Lq_np2LpSrxj84JpcbzytL449DH8E"
# Corpus Toutes Langues Médical Médecine Générale
corpus_trad_med_neu = "ASAMLA - Corpus Médical Médecine Générale-Traduction-v1.0"
corpus_trad_med_neu_uri = "https://docs.google.com/spreadsheets/d/1CvF6qiO_bYSG5pLWDc3gBoNc2NE09-2g5jopQ8Ax09A"
corpus_trad_med_neu_uri = "https://docs.google.com/spreadsheets/d/1zB7hvjr2HufHcVgcJfEtrUUmR75wU5OCiL-_d4oDtTU"

# %% [markdown]
# Ouverture de la base centrale (repository) : base se trouvant sur gdrive atos.net

# %%
# Ouverture de la Sheet Centrale (corpus_central_base)
sheet_central = 'https://docs.google.com/spreadsheets/d/1L8YB1aXHUJwUE9AE6xyn_xMHalinGR335Q7lntwbu1U'
wb_central = gc.open_by_url(sheet_central)
# onglet Médical Vaccination
corpus_trad_med_vac_onglet = "med_vac_synthese"
# onglet Médical Médecine Générale
corpus_trad_med_gen_onglet = "med_gen_synthese"

# %% [markdown]
# Chargement du Corpus FR : à ce stade, il ne contient que des expressions en français

# %%
def get_cc_config(cfg):
  vk_lang_dict = []
  try:
    with open(cfg) as vk_dict:
        vk_lang_dict = json.load(vk_dict)
  except BaseException as e:
    print(e)
  return vk_lang_dict

def set_cc_config (vk_lang_dict, cfg):
  # sauvegarde du fichier de paramétrage
  with open(cfg, 'w') as fp:
      json.dump(vk_lang_dict, fp)

# %%
lang_config = 'med_vac_synthese.json'
vk_lang_dict = get_cc_config(lang_config)

# %%
uri = corpus_fr_med_gen_uri

# %%
uri
# Out:
# 'https://docs.google.com/spreadsheets/d/1M3CFSpAGII25qCl0apYrRPX-DmpdxDFLLB_Ob-MX8DQ'

# %%
def narrow_no_break_space (s):
  s = " ".join(s.split())   # on vire tous les espaces en trop
  find = r'(\s*\?$)'        # on recherche le ? précédé ou pas d'espace \s*
  replace = u'\u202F'+ r'?'
  s = re.sub(find, replace, s)    # on remplace par un blanc insécable + le ?
  return s

# %% [markdown]
# Fonction d'attribution d'id unique pour chaque expression à l'intérieur d'un corpus

# %%
#ouverture de l'onglet Corpus dans un DF
wb = gc.open_by_url(uri)
t_corpus = wb.get_worksheet(0)
data_t_corpus = t_corpus.get_all_values()
df_corpus = pd.DataFrame(data_t_corpus[1:], columns=data_t_corpus[0])

# %%
df_corpus
# Out:
#          uid                                           français                    état
# 0   f9bc13ef  À quel moment de la journée prenez-vous le méd...  Ne rien traduire ici !
# 1   6e65dde7                                              Abcès  Ne rien traduire ici !
# 2   1178fb77                                 Analyse des urines  Ne rien traduire ici !
# 3   ef2f771b                                Anesthésie générale  Ne rien traduire ici !
# 4   a2668f5a                        Anesthésie locale/régionale  Ne rien traduire ici !
# ..       ...                                                ...                     ...
# 83  c32f5fd9  Y a-t-il des maladies chroniques dans votre fa...  Ne rien traduire ici !
# 84  ebaf8e32                                            Médecin  Ne rien traduire ici !
# 85  76ae390d                                  Médecine générale  Ne rien traduire ici !
# 86  ca2eb80a                                       Consultation  Ne rien traduire ici !
# 87  de77211f           Quelle est le motif de la consultation ?  Ne rien traduire ici !
#
# [88 rows x 3 columns]

# %%
# si le uid est vide, on le crée
df_corpus['uid'] = df_corpus[['uid','état']].apply(lambda x: x[0] if x[0]!="" else make_unique_id(), axis=1)
df_corpus['uid'] = df_corpus['uid'].astype("string")

# %%
# on élimine toutes les lignes sans expression
df_corpus["français"].replace('', np.nan, inplace=True)
df_corpus = df_corpus[df_corpus['français'].notna()]
# trim des expressions
df_corpus['français'] = df_corpus['français'].apply(lambda x:x.strip())
df_corpus['français'] = df_corpus['français'].apply(lambda x:narrow_no_break_space(x))

# %%
df_corpus['état'] = df_corpus['état'].apply(lambda x:"Ne rien traduire ici !")

# %%
# sauvegarde du dataframe dans la table Liste des expressoins à traduire
set_with_dataframe(t_corpus, df_corpus)

# %%
# on ne conserve que les colonnes utiles
# on ajoute la colonne pour la traduction
df_corpus['traduction'] = ''
df_corpus = df_corpus[['uid','français','traduction','état']]

# %% [markdown]
# Sauvegarde du corpus FR avec l'uid

# %%
# on charge le contenu des onglets existants
uri = corpus_trad_med_neu_uri
#ouverture de l'onglet Corpus dans un DF
wbt = gc.open_by_url(uri)
vk_trad = []
#pour chaque corpus, on créé un onglet si besoin
for index, item in enumerate(vk_lang_dict):
  nom_onglet = item['language']
  print ("Processing " + nom_onglet)  
  t_temp = wbt.worksheet(nom_onglet)
  data_t_temp = t_temp.get_all_values()
  df_temp = pd.DataFrame(data_t_temp[1:], columns=data_t_temp[0]).drop_duplicates()  
  df_temp = df_temp[['uid','français', 'traduction']]
  new_df=df_corpus.merge(df_temp, on='uid', how='left')
  new_df.drop(['français_y', 'traduction_x'], axis=1, inplace=True)
  new_df.rename(columns={'français_x': 'français', 'traduction_y': 'traduction'}, inplace=True) 
  new_df.sort_values(by=['français']) 
  new_df['traduction'] = new_df['traduction'].apply(lambda x:x.strip() if x is not np.nan else "")
  new_df['traduction'] = new_df['traduction'].apply(lambda x:narrow_no_break_space(x))   
  new_df = new_df[['uid','français', 'traduction']]  
  vk_trad.append(new_df)
  # si l'onglet existe déjà, on le supprime ?
  try:
    ws = wbt.worksheet(nom_onglet)
    wbt.del_worksheet(ws)  
  except:
    print ("Onglet inexistant !")
    print ("Non existing : " + nom_onglet)
  wbt.add_worksheet(nom_onglet, 1, 1)
  export_sheet = wbt.worksheet(nom_onglet)
  set_with_dataframe(export_sheet, new_df)
  format_feuille(wbt, nom_onglet)
# Out:
# Processing Arabe
# Processing Anglais
# Processing Turc
# Processing Russe
# Processing Ukrainien
# Processing Roumain
# Processing Hongrois
# Processing Tigrinya
# Processing Albanais
# Processing Géorgien
# Processing Arménien
# Processing Dari
# Processing Pashto
# Processing Fârsi
# Processing Azéri
# Processing Espagnol
# Processing Amharique
# Processing Allemand
# Processing Polonais
# Processing Somali

# %% [markdown]
# #### Déploiement du corpus français dans un corpus de traduction : 1 langue = 1 onglet

# %% [markdown]
# END

# %%
pd.merge(left=df_corpus, right=vk_trad[0], 
                      how='outer',
                      left_index=True,
                      right_index=True,
                      on=('uid')
                     ).sort_index(axis=1)
# Out:
#                                            français_x  ...       uid
# 0   À quelle moment de la journée prenez-vous le m...  ...  f9bc13ef
# 1                         Votre poids a-t-il baissé ?  ...  0e9f09c9
# 2                                               Abcès  ...  6e65dde7
# 3                                  Analyse des urines  ...  1178fb77
# 4                                 Anesthésie générale  ...  ef2f771b
# ..                                                ...  ...       ...
# 88          Vous avez des allergies aux médicaments ?  ...  00052418
# 89                         Vous avez mal autre part ?  ...  5baecf7f
# 90                                 Où avez-vous mal ?  ...  3691346a
# 91                          De quel pays venez-vous ?  ...  192bc4c8
# 92  Y a-t-il des maladies chroniques dans votre fa...  ...  c32f5fd9
#
# [93 rows x 5 columns]

# %%
new_df=df_corpus.merge(vk_trad[0], on='uid', how='left')

# %%
new_df
# Out:
#          uid                                           français      traduction
# 2   6e65dde7                                              Abcès          خُرّاج
# 3   1178fb77                                 Analyse des urines
# 4   ef2f771b                                Anesthésie générale
# 5   a2668f5a                        Anesthésie locale/régionale
# 6   6fa427fc                                             Angine
# ..       ...                                                ...             ...
# 92  c32f5fd9  Y a-t-il des maladies chroniques dans votre fa...
# 0   f9bc13ef  À quelle moment de la journée prenez-vous le m...
# 40  7768882c                               Êtes-vous enceinte ?
# 39  c5df267a                            Êtes-vous vacciné (e) ?  هل تمّ تطعيمك؟
# 60  72f0e8db                                              Œdème
#
# [93 rows x 3 columns]

# %%
new_df.drop(['français_y', 'traduction_x'], axis=1, inplace=True)

# %%
new_df.rename(columns={'français_x': 'français', 'traduction_y': 'traduction'}, inplace=True)

# %%
new_df.sort_values(by=['français'], inplace=True)

# %%
new_df['traduction'] = new_df['traduction'].apply(lambda x:x.strip() if x is not np.nan else "")
new_df['traduction'] = new_df['traduction'].apply(lambda x:narrow_no_break_space(x))

# %%
uri = corpus_trad_med_neu_uri
#ouverture de l'onglet Corpus dans un DF
wb = gc.open_by_url(uri)
#pour chaque corpus, on créé un onglet si besoin
for index, item in enumerate(vk_lang_dict):
  #df_corpus_all.append (df_corpus)
  nom_onglet = item['language']
  print ("Processing " + nom_onglet)  
  # si l'onglet existe déjà, on le supprime ?
  try:
    ws = wb.worksheet(nom_onglet)
    wb.del_worksheet(ws)  
  except:
    print ("Onglet inexistant !")
    print ("Non existing : " + nom_onglet)
  wb.add_worksheet(nom_onglet, 1, 1)
  export_sheet = wb.worksheet(nom_onglet)
  set_with_dataframe(export_sheet, df_corpus)
  format_feuille(wb, nom_onglet)
# Out:
# Processing Arabe
# Processing Anglais
# Processing Turc
# Processing Russe
# Processing Ukrainien
# Processing Roumain
# Processing Hongrois
# Processing Tigrinya
# Processing Albanais
# Processing Géorgien
# Processing Arménien
# Processing Dari
# Processing Pashto
# Processing Fârsi
# Processing Azéri
# Processing Espagnol
# Processing Amharique
# Processing Allemand
# Processing Polonais
# Onglet inexistant !
# Non existing : Polonais
# Processing Somali
# Onglet inexistant !
# Non existing : Somali

# %%
uri = corpus_trad_med_neu_uri
#ouverture de l'onglet Corpus dans un DF
wb = gc.open_by_url(uri)
#pour chaque corpus, on créé un onglet si besoin
for index, item in enumerate(vk_lang_dict):
  #df_corpus_all.append (df_corpus)
  nom_onglet = item['language']
  print ("Processing " + nom_onglet)
  # si l'onglet existe déjà, on le supprime ?
  try:
    ws = wb.worksheet(nom_onglet)
    data_onglet = ws.get_all_values()
    df_onglet = pd.DataFrame(data_onglet[1:], columns=data_onglet[0])
    # fusion des données présentes et nouvelles
    frames = [df_onglet, df_corpus]
    result = pd.concat([df_onglet, df_corpus]).drop_duplicates('uid').reset_index(drop=True)
    set_with_dataframe(ws, result)
    format_feuille(wb, nom_onglet)     
  except:
    print ("Onglet inexistant !")
    print ("Non existing : " + nom_onglet)
    wb.add_worksheet(nom_onglet, 1, 1)
    export_sheet = wb.worksheet(nom_onglet)
    set_with_dataframe(export_sheet, df_corpus)
    format_feuille(wb, nom_onglet)

# %%
nom_onglet = 'Turc'
ws = wb.worksheet(nom_onglet)
data_onglet = ws.get_all_values()
df_onglet = pd.DataFrame(data_onglet[1:], columns=data_onglet[0])

# %%
pd.merge(left=df_corpus, right=df_onglet, 
                      how='outer',
                      left_index=True,
                      right_index=True,
                      on=('uid')
                     ).sort_index(axis=1)
# Out:
#    commentaires_x commentaires_y      date_x  ...       uid  état_x  état_y
# 0                                 09/12/2021  ...  03bb6e86  validé
# 1                                 09/12/2021  ...  38a24ddb  validé
# 2                                 09/12/2021  ...  ba312208  validé
# 3                                 09/12/2021  ...  192bc4c8  validé
# 4                                 09/12/2021  ...  955f030c  validé
# ..            ...            ...         ...  ...       ...     ...     ...
# 79                                09/12/2021  ...  af9faaa5  validé
# 80                                09/12/2021  ...  1ffe71ca  validé
# 81                                09/12/2021  ...  6fa427fc  validé
# 82                                09/12/2021  ...  72f0e8db  validé
# 83            NaN                        NaN  ...     52418     NaN  validé
#
# [84 rows x 11 columns]

# %%
df_onglet
# Out:
#          uid                                   français  ... commentaires    état
# 0   03bb6e86       Bonjour, comment vous appelez-vous ?  ...
# 1   38a24ddb        Quel est le motif de votre visite ?  ...
# 2   ba312208                       Quel âge avez-vous ?  ...
# 3   192bc4c8                  Vous venez de quel pays ?  ...
# 4   955f030c                   Buvez-vous de l’alcool ?  ...
# ..       ...                                        ...  ...          ...     ...
# 79  af9faaa5                                   Purulent  ...
# 80  1ffe71ca                                    Fatigue  ...
# 81  6fa427fc                                     angine  ...
# 82  72f0e8db                                     oedème  ...
# 83     52418  Vous avez des allergies aux médicaments ?  ...               validé
#
# [84 rows x 6 columns]

# %%
new_df = df_onglet.merge(df_corpus, on='uid', how='left')
new_df.drop(['français_x', 'date_x','commentaires_x','traduction_y','état_x'], axis=1, inplace=True)
new_df.rename(columns={'traduction_x': 'traduction', 'français_y': 'français','date_y': 'date', 'commentaires_y': 'commentaires', 'état_y': 'état'})
# Out:
#          uid                   traduction  ... commentaires    état
# 0   03bb6e86     Merhaba isminiz  nedir ?  ...               validé
# 1   38a24ddb            niçin burdasınız?  ...               validé
# 2   ba312208             kaç yaşındasınız  ...               validé
# 3   192bc4c8  hangi ûlkeden geliyorsunuz?  ...               validé
# 4   955f030c         alkol içiyormusunuz?  ...               validé
# ..       ...                          ...  ...          ...     ...
# 79  af9faaa5                    iltihaplı  ...               validé
# 80  1ffe71ca                    yorgunluk  ...               validé
# 81  6fa427fc                               ...               validé
# 82  72f0e8db                               ...               validé
# 83     52418                               ...          NaN     NaN
#
# [84 rows x 6 columns]

# %%
df_onglet['français']=
# Out:
#          uid                                   français  ... commentaires    état
# 0   03bb6e86       Bonjour, comment vous appelez-vous ?  ...
# 1   38a24ddb        Quel est le motif de votre visite ?  ...
# 2   ba312208                       Quel âge avez-vous ?  ...
# 3   192bc4c8                  Vous venez de quel pays ?  ...
# 4   955f030c                   Buvez-vous de l’alcool ?  ...
# ..       ...                                        ...  ...          ...     ...
# 79  af9faaa5                                   Purulent  ...
# 80  1ffe71ca                                    Fatigue  ...
# 81  6fa427fc                                     angine  ...
# 82  72f0e8db                                     oedème  ...
# 83     52418  Vous avez des allergies aux médicaments ?  ...               validé
#
# [84 rows x 6 columns]

# %%
for i in vk_lang_dict:
  i['wals_code']=''

# %%
vk_lang_dict
# Out:
# [{'alphabet': 'اآٱأإبتثجحخدذرزسشصضطظعغفقكلمنهةوؤيئىء',
#   'credits': 'Sonia ZARROUK, Wafa TAHRI',
#   'font-family': 'DejaVuSans',
#   'font-family-bold': 'DejaVuSans-Bold',
#   'font-path': '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf',
#   'glossary-subtitle': 'عربي فرنسي',
#   'idx': 1,
#   'language': 'Arabe',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'rtl',
#   'trigramme': 'ams',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '134rEeVux-FvSxPt4EO4OM1M8PnGHa6P1ewtmnsnRfrs',
#   'wals_code': ''},
#  {'alphabet': 'AaBbCcDdEeFfGgHhIiJjKkLlMmNnOoPpQqRrSsTtUuVvWwXxYyZz',
#   'credits': 'Khalida BENHEDDER',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'English-French',
#   'idx': 2,
#   'language': 'Anglais',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'eng',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1r0pPfeZtS2EhMwWa1VpU0HiisFcYQ6T7oi4OInEMQPE',
#   'wals_code': ''},
#  {'alphabet': 'AaÂâBbCcÇçDdEeFfGgĞğHhIıİiÎîJjKkLlMmNnOoÖöPpRrSsŞşTtUuÜüÛûVvYyZz',
#   'credits': 'Gülseren AKKOÇ',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'Türkçe-Fransizca',
#   'idx': 3,
#   'language': 'Turc',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'tur',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1yQ114R7Jyo-HasGlIBQw7ThdK0uVEFRr1WCJeEMT4s0',
#   'wals_code': ''},
#  {'alphabet': 'АаБбВвГгДдЕеЁёЖжЗзИиЙйКкЛлМмНнОоПпРрСсТтУуФфХхЦцЧчШшЩщЪъЫыЬьЭэЮюЯя',
#   'credits': 'Natalia SAVELIEVA',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'Русско-французский',
#   'idx': 4,
#   'language': 'Russe',
#   'meta': {'credits-fr': 'Traduction : Natalia SAVELIEVA',
#    'credits-tr': 'Перевод : Наталья САВЕЛЬЕВА',
#    'subtitle-fr': 'Français-Russe',
#    'subtitle-tr': 'Русско-Французский',
#    'title-fr': 'Vaccination',
#    'title-tr': 'Вакцинация'},
#   'text-direction': 'ltr',
#   'trigramme': 'rus',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1Z5mAYaqKkzoykbTwnFmOS2A468W37_y-bwoHAxwQp8M',
#   'wals_code': ''},
#  {'alphabet': 'АаБбВвГгҐґДдЕеЄєЖжЗзИиІіЇїЙйКкЛлМмНнОоПпРрСсТтУуФфХхЦцЧчШшЩщЮюЯя',
#   'credits': 'Natalia SAVELIEVA',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'Українсько-французька',
#   'idx': 5,
#   'language': 'Ukrainien',
#   'meta': {'credits-fr': 'Traduction : Natalia SAVELIEVA',
#    'credits-tr': 'Переклад : Наталія САВЕЛЬЄВА',
#    'subtitle-fr': 'Français-Ukrainien',
#    'subtitle-tr': 'Українсько-Французький',
#    'title-fr': 'Vaccination',
#    'title-tr': 'Вакцинація'},
#   'text-direction': 'ltr',
#   'trigramme': 'ukr',
#   'unicode_substition': [['A', 'A', 'А'],
#    ['B', 'B', 'В'],
#    ['E', 'E', 'Е'],
#    ['I', 'I', 'І'],
#    ['K', 'K', 'К'],
#    ['M', 'M', 'М'],
#    ['P', 'P', 'Р'],
#    ['T', 'T', 'Т']],
#   'update': 'false',
#   'uri': '16gWyW1_7z1OOt_ssYHL8iCCZGjOjQ5Wtfbkew9_uvnw',
#   'wals_code': ''},
#  {'alphabet': 'AaĂăÂâBbCcDdEeFfGgHhIiÎîJjKkLlMmNnOoPpQqRrSsȘșTtȚțUuVvWwXxYyZz',
#   'credits': 'Annamaria LOCSE, Alexandra DEACONESCU, Ramona MIHAILOV',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'ROMÂNĂ-FRANCEZĂ',
#   'idx': 6,
#   'language': 'Roumain',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'rou',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '11eVHnQJTt5MY4GCXNRYwKMriZ3XBUUY_-N7uoPQR-9U',
#   'wals_code': ''},
#  {'alphabet': 'Aa-Áá-Bb-Cc-Cscs-Dd-Ee-Éé-Ff-Gg-Gygy-Hh-Ii-Íí-Jj-Kk-Ll-Lyly-Mm-Nn-Oo-Óó-Öö-Őő-Pp-Qq-Rr-Ss-Szsz-Tt-Tyty-Uu-Úú-Üü-Űű-Vv-Ww-Xx-Yy-Zz-Zszs',
#   'credits': 'Annamaria LOCSE',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'Magyar-Francia',
#   'idx': 7,
#   'language': 'Hongrois',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'hun',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1oTh6b6TciHCcgzjUHqtG-qh6if2dD2LPg_uAC4IxfF4',
#   'wals_code': ''},
#  {'alphabet': 'ሀሁሂሃሄህሆለሉሊላሌልሎሏሐሑሒሓሔሕሖሗመሙሚማሜምሞሟሠሡሢሣሤሥሦሧረሩሪራሬርሮሯሰሱሲሳሴስሶሷሸሹሺሻሼሽሾሿቀቁቂቃቄቅቆቇቐቑቒቓቔቕቖበቡቢባቤብቦቧቨቩቪቫቬቭቮቯተቱቲታቴትቶቷቸቹቺቻቼችቾቿኀኁኂኃኄኅኆኇነኑኒናኔንኖኗኘኙኚኛኜኝኞኟአኡኣኤእኦኧከኩኪካኬክኮኯኸኹኺኻኼኽኾወዉዊዋዌውዎዐዑዒዓዔዕዖዘዙዚዛዜዝዞዟዠዡዢዣዤዥዦዧየዩዪያዬይዮዯደዱዲዳዴድዶዷዸዹዺዻዼዽዾዿጀጁጂጃጄጅጆጇገጉጊጋጌግጎጏጘጙጚጛጜጝጞጟጠጡጢጣጤጥጦጧጨጩጪጫጬጭጮጯጰጱጲጳጴጵጶጷጸጹጺጻጼጽጾጿፀፁፂፃፄፅፆፇፈፉፊፋፌፍፎፏፐፑፒፓፔፕፖፗቈቊቋቌቍቘቚቛቜቝኈኊኋኌኍኰኲኳኴኵዀዂዃዄዅጐጒጓጔጕ',
#   'credits': 'Rozina ASMERON, Yirgalem TEKLABE',
#   'font-family': 'jiret',
#   'font-family-bold': 'jiret',
#   'font-path': '/content/drive/MyDrive/Trad-Union/Corpus/ASAMLA/jiret.ttf',
#   'glossary-subtitle': '',
#   'idx': 8,
#   'language': 'Tigrinya',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'tig',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '17boObdqNVhvWAcoLo1gVUXIc493VeI2a0GmqEPwnouk',
#   'wals_code': ''},
#  {'alphabet': 'Aa-Bb-Cc-Çç-Dd-Dhdh-Ee-Ëë-Ff-Gg-Gjgj-Hh-Ii-Jj-Kk-Ll-Llll-Mm-Nn-Njnj-Oo-Pp-Qq-Rr-Rrrr-Ss-Shsh-Tt-Thth-Uu-Vv-Ww-Xx-Xhxh-Yy-Zz-Zhzh',
#   'credits': 'Xhemshit ALITI',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 9,
#   'language': 'Albanais',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'alb',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1DUS39fYPk6Nw9u7Gzr5UkDducAHbMnMtyMegJgKyVMk',
#   'wals_code': ''},
#  {'alphabet': 'ᲐᲑᲒᲓᲔᲕᲖᲗᲘᲙᲚᲛᲜᲝᲞᲟᲠᲡᲢᲣᲤᲥᲦᲧᲨᲩᲪᲫᲬᲭᲮᲯᲰ',
#   'credits': 'Nina PRIMAKOFF',
#   'font-family': 'arial_geo',
#   'font-family-bold': 'arial_geo-bold',
#   'font-path': '/content/drive/MyDrive/Trad-Union/Corpus/ASAMLA/arial_geo.ttf',
#   'glossary-subtitle': 'ქართულ-ფრანგული ლექსიკა',
#   'idx': 10,
#   'language': 'Géorgien',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'geo',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '17Z9nFomcHS32SOZdVh_C0CfozVNyn8ipz6qbg1EAmH4',
#   'wals_code': ''},
#  {'alphabet': 'ԱաԲբԳգԴդԵեԶզԷէԸըԹթԺժԻիԼլԽխԾծԿկՀհՁձՂղՃճՄմՅյՆնՇշՈոՉչՊպՋջՌռՍսՎվՏտՐրՑցՒւՓփՔքՕօՖֆև',
#   'credits': 'Nuné DZHALALYAN',
#   'font-family': 'NotoSerifArmenian-Regular',
#   'font-family-bold': 'NotoSerifArmenian-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerifArmenian-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 11,
#   'language': 'Arménien',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'arm',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '11MtxyUVEGfZZjmCDuQzDL75if7oEr9rspRvhjE06EW4',
#   'wals_code': ''},
#  {'alphabet': 'اآبپتثجچحخدذرزژسشصضطظعغفقکگلمنوهی',
#   'credits': 'Massouda et Yalda HEMATYAR',
#   'font-family': 'Adobe Arabic Regular',
#   'font-family-bold': 'DejaVuSans-Bold',
#   'font-path': '/content/drive/MyDrive/Trad-Union/Corpus/ASAMLA/resources/Adobe Arabic Regular.ttf',
#   'glossary-subtitle': 'دری-فرانسوی',
#   'idx': 12,
#   'language': 'Dari',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'rtl',
#   'trigramme': 'dar',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1P-s03l6quqA2OvYWD_PgvPzl9CKraRRNbJFTF50WrsI',
#   'wals_code': ''},
#  {'alphabet': 'اآبپتثجچحخدذرزژسشصضطظعغفقکگلمنوهی',
#   'credits': 'Massouda et Yalda HEMATYAR',
#   'font-family': 'Adobe Arabic Regular',
#   'font-family-bold': 'Adobe Arabic Regular',
#   'font-path': '/content/drive/MyDrive/Trad-Union/Corpus/ASAMLA/resources/Adobe Arabic Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 13,
#   'language': 'Pashto',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'rtl',
#   'trigramme': 'pst',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1IDUQ_SlSOMWX87NrwwZ94SBcNYEoPx-hz7lgC5c5FO8',
#   'wals_code': ''},
#  {'alphabet': 'اآبپتثجچحخدذرزژسشصضطظعغفقکگلمنوهی',
#   'credits': 'Massouda et Yalda HEMATYAR',
#   'font-family': 'Adobe Arabic Regular',
#   'font-family-bold': 'DejaVuSans-Bold',
#   'font-path': '/content/drive/MyDrive/Trad-Union/Corpus/ASAMLA/resources/Adobe Arabic Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 14,
#   'language': 'Fârsi',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'rtl',
#   'trigramme': 'prs',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '17agq-TEjL_SUJ16r0YaArlTAorQYf1aj4PuX4BSz7TE',
#   'wals_code': ''},
#  {'alphabet': '',
#   'credits': '',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 15,
#   'language': 'Azéri',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'aze',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1g7Y20Gm5NYamsasK1KzUuVPVg6RMrzSyyWUOJZHyNko',
#   'wals_code': ''},
#  {'alphabet': 'AaÁáBbCcDdEeÉéFfGgHhIiÍíJjKkLlMmNnÑñOoÓóPpQqRrSsTtUuÚúÜüVvWwXxYyZz',
#   'credits': 'Chloé SMALL',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': 'Español-Francés',
#   'idx': 16,
#   'language': 'Espagnol',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'esp',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1Jj0FiQqKikotBpGUomjsg3_VnWB8zoCDNn66lRDECSo',
#   'wals_code': ''},
#  {'alphabet': '',
#   'credits': '',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 17,
#   'language': 'Amharique',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'amh',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '11o9tKQSBVRARQhdHOKcQ848rcWnaV6MAkKD0Jm70Xy4',
#   'wals_code': ''},
#  {'alphabet': 'AaÄäBbCcDdEeFfGgHhIiJjKkLlMmNnOoÖöPpQqRrSsẞßTtUuÜüVvWwXxYyZz',
#   'credits': 'Canan SIMSEK',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 18,
#   'language': 'Allemand',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'all',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '1KTwgp5cZh7_PINkwRV-dK-77w_f8XrL_GglFZ44XJvs',
#   'wals_code': ''},
#  {'alphabet': 'AaÄäBbCcDdEeFfGgHhIiJjKkLlMmNnOoÖöPpQqRrSsẞßTtUuÜüVvWwXxYyZz',
#   'credits': 'Jolanta Folwarska',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 19,
#   'language': 'Polonais',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'pol',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '',
#   'wals_code': ''},
#  {'alphabet': '',
#   'credits': 'Linda SEIF KAYED',
#   'font-family': 'NotoSerif-Regular',
#   'font-family-bold': 'NotoSerif-Bold',
#   'font-path': '/usr/share/fonts/truetype/noto/NotoSerif-Regular.ttf',
#   'glossary-subtitle': '',
#   'idx': 20,
#   'language': 'Somali',
#   'meta': {'credits-fr': '',
#    'credits-tr': '',
#    'subtitle-fr': '',
#    'subtitle-tr': '',
#    'title-fr': '',
#    'title-tr': ''},
#   'text-direction': 'ltr',
#   'trigramme': 'som',
#   'unicode_substition': [],
#   'update': 'false',
#   'uri': '',
#   'wals_code': ''}]

# %%
set_cc_config(vk_lang_dict, lang_config)
